# %% [markdown]
# TextRank for Document Summarization

# %%
import re #rehex as regression
import numpy as np

import networkx as nx
import nltk

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

# %%
text="""India, officially the Republic of India,[j][20] is a country in South Asia. It is the seventh-largest country by area; the most populous country since 2023;[21] and, since its independence in 1947, the world's most populous democracy.[22][23][24] Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west;[k] China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east. In the Indian Ocean, India is near Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Myanmar, Thailand, and Indonesia."""
text = re.sub(r'\[.*?\]', '', text)
print(text)
# Out:
# India, officially the Republic of India, is a country in South Asia. It is the seventh-largest country by area; the most populous country since 2023; and, since its independence in 1947, the world's most populous democracy. Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west; China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east. In the Indian Ocean, India is near Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Myanmar, Thailand, and Indonesia.

# %%
def preprocess_sentence(sentence):
  stop_words=set(stopwords.words("english"))
  words=word_tokenize(sentence.lower())
  words=[w for w in words if w.isalnum() and w not in stop_words]
  return words

# %%
def sentence_similarity(sent1,sent2):
  words1=preprocess_sentence(sent1)
  words2=preprocess_sentence(sent2)
  all_words=list(set(words1+words2))
#VECTORIZATION
  vector1=[words1.count(w) for w in all_words]
  vector2=[words2.count(w) for w in all_words]

  if sum(vector1)==0 or sum(vector2)==0:
    return 0
  return np.dot(vector1,vector2)/(np.linalg.norm(vector1)*np.linalg.norm(vector2))

# %%
def similarity_matrix(sentences):
  n=len(sentences)
  sim_matrix=np.zeros((n,n))

  for i in range (n):
    for j in range (n):
      sim_matrix[i][j]=sentence_similarity(sentences[i],sentences[j])
  return sim_matrix

# %%
def textrank_summarization(text,top=3):
  sentences=sent_tokenize(text)
  sim_matrix=similarity_matrix(sentences)
  graph=nx.from_numpy_array(sim_matrix)
  scores=nx.pagerank(graph)
  ranked_sentences=sorted(((scores[i],s) for i,s in enumerate(sentences)),reverse=True)
  summary=[sentence for score, sentence in ranked_sentences[:top]]
  return " ".join(summary)

# %%
print(textrank_summarization(text))
# Out:
# India, officially the Republic of India, is a country in South Asia. In the Indian Ocean, India is near Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Myanmar, Thailand, and Indonesia. Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west; China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east.
